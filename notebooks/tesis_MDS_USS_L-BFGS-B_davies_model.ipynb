# %% [markdown]
# ## 1. Data Loading and Exploration

# %% [markdown]
# ### 1.1 Modules and Libraries

# %%
from pickle import TRUE
import numpy as np
import torch
import time
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from scipy.signal import find_peaks
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

FOLDER_PATH = '/content/drive/MyDrive/Colab Notebooks/data_model_davies'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1.2 Numerical Parameters

# %%
# Numerical parameters
nlat = 78
nlon = 71
nz = 500 # Initial number of rioters

Lr = 6 # most recent time steps in our discretised temporal scheme
Lp = 12 # response lag of the police units

Nt = 500 # Rate at which individuals choose to participate at time t
Ntt = 10

dt = 0.1 # delta time
sim_time = 0.0 # init time

# %% [markdown]
# ### 1.3 Simulation Parameters

# %%
# Simulation parameters

# alpha_r: Attractiveness of a retail site to rioters (It is the parameter associated with the size of the retail location.)
# beta_r: Distance decay parameter for rioters (It influences how the distance between a rioter's residence and a potential
#         target affects the attractiveness of that target)
# gamma_r: Deterrent effect of police presence (It is a factor in the term that modifies the attractiveness of location j based
#          on the number of police officers and rioters, so it is a measure of how much the presence of police will deter a rioter)

alpha_r = 0.5
beta_r = 0.5
gamma_r = 0.11

mu = 1.0 # This is an exponent in the function for the probability of rioting in an area, related to how deprivation affects the likelihood of rioting

# alpha_p: Attractiveness of a location to police. It influences how police resources are allocated based on the characteristics of the location.
# gamma_p: Impact of the number of rioters on the police requirement at a site.

alpha_p = 1.0
gamma_p = 0.01

eta = 0.005 # Infection rate. It determines how quickly individuals are influenced by the ongoing disorder and become active rioters
tau = 0.75 # Arrest rate parameter. It determines how quickly rioters are arrested by police when they are present
Ptotal = 500.0  # Total number of police forces

# %% [markdown]
# ### 1.4 Data Sources

# %%
# Data sources

# Initial data arrays
origin = np.loadtxt(f"{FOLDER_PATH}/origin_dens_500m_5am10am.dat") # Origin
destination = np.loadtxt(f"{FOLDER_PATH}/destination_dens_500m_5am10am.dat") # Destination

# i: Residential Área
# j: Retail Center (Potential Riot Site)
Zj = np.loadtxt(f"{FOLDER_PATH}/targets_500.dat")  # Targets (Benefit for j site is given by the logarithm of Zj a non-dimensional measure of its relative value)
dij = np.load(f"{FOLDER_PATH}/rij_500_no_network.npy")  # Ponderated distances (the distance between the centroids of i and j)
Dj_cl= np.loadtxt(f"{FOLDER_PATH}/data_sosafe.dat") # Data from SOSAFE (real data)

# Population, Police and Rioters
Ii = origin + destination  # Inactive population (the number of inactive individuals resident in area i)
Ai = np.zeros((nlat, nlon), "d")  # Active population
Ci = np.zeros((nlat, nlon), "d")  # Capture rate
rho = np.ones((nlat, nlon), "d")  # Deprivation distribution (is a measure of the deprivation in i)

Rj = np.zeros(nz, "d")  # Rioters (Ri: the number of rioters whose residece in in a given zone i)
# Rj = np.loadtxt('Rj_init.dat') # Initial 100 rioters distribution
Pj = np.zeros(nz, "d")  # Police officers
We_ij = np.zeros((nlat, nlon, nz), "d")  # Benefit computation (We_ij: effective attractiveness)
fjdel = np.zeros((nz, Lr), "d")  # Delayed effect computation
Sij = np.zeros((nlat, nlon, nz), "d")  # Population flow between i and j (An estimate of the number of rioters from i who are participating in disorder in j at time t)
Dj = np.zeros(nz, "d")  # The number of rioters in j
Ddel = np.zeros((nz, Lp), "d")  # Police requirement, time-delayed
Dej = np.zeros(nz, "d")

# %% [markdown]
# #### GD

# %%
# Escalar objetivo
scaler = MinMaxScaler()
scaled_targets = scaler.fit_transform(Zj[:, 2].reshape(-1, 1)).flatten() # (500, 1)

# %%
def run_simulation(dij_sim, Ii, Zj, beta_r, gamma_r, alpha_p, gamma_p):

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    Zj_t = torch.from_numpy(Zj).to(device)
    Ii_t = torch.from_numpy(Ii).to(device)
    dij_t = torch.from_numpy(dij_sim).to(device)

    Lr, Lp = 6, 12
    eta, tau, Ptotal = 0.005, 0.75, 500.0
    counter, idxr, idxp, t, dt = 0, 0, 0, 0, 0.1
    Nt, Ntt, nlat, nlon, nz = 500, 10, 78, 71, 500

    Rj_t = torch.from_numpy(np.zeros(nz, "d")).to(device)
    Ai_t = torch.from_numpy(np.zeros((nlat, nlon), "d")).to(device)
    Pj_t = torch.from_numpy(np.zeros(nz, "d")).to(device)
    Ci_t = torch.from_numpy(np.zeros((nlat, nlon), "d")).to(device)
    fjdel_t = torch.from_numpy(np.zeros((nz, Lr), "d")).to(device)
    rho_t = torch.from_numpy(np.ones((nlat, nlon), "d")).to(device)
    Ddel_t = torch.from_numpy(np.zeros((nz, Lp), "d")).to(device)
    Dj_t = torch.from_numpy(np.zeros(nz, "d")).to(device)

    auxij1 = torch.exp(-beta_r * dij_t)
    dij_t = 1.0 * Zj_t[:, 2] * auxij1 / torch.max(Zj_t[:, 2])

    print("Starting loop ...")
    timer0 = time.time()

    for nn in range(Nt):
        for mm in range(Ntt):
            fj_t = torch.exp(-torch.floor(gamma_r * Pj_t / (Rj_t + 1.0e-20))) # 500 Values
            Wij_t = fj_t * dij_t # Dj shape: 78, 71, 500 (Broadcasting) --> Attractiveness term ij
            Wi_t = Wij_t.sum(dim=2) # Wi shape: 78, 71 each value is the sum of 500 values (fj) --> Attractiveness term i
            P_off_t = rho_t * Wi_t / (1.0 + Wi_t) # P_off shape: 78, 71
            idxr = counter - (Lr) * int(counter / Lr) # Lr: 6, idxr: 0-5
            fjdel_t[:, idxr] = fj_t # fjdel: 500, 6
            dnm = Lr if counter >= Lr else counter + 1
            We_ij_t = fjdel_t.sum(dim=1) * dij_t / dnm # Delayed term computation
            auxw = Ai_t / (We_ij_t.sum(dim=2) + 1.0e-20)  # Flow computation step 1i
            Sij_t = auxw[:, :, torch.newaxis] * We_ij_t # Flow computation step 2
            Rj_t = torch.sum(Sij_t.sum(dim=1), dim=0) # Rioter computation
            Dj_t[:] = Zj_t[:, 2] ** (alpha_p) * torch.exp(gamma_p * Rj_t[:]) # Police Interaction
            idxp = counter - (Lp) * int(counter / Lp) # Delayed term computation
            Ddel_t[:, idxp] = Dj_t[:]
            dnm = Lp if counter >= Lp else counter + 1
            Dej_t = torch.sum(Ddel_t, dim=1) / dnm
            Pj_t = Ptotal * Dej_t / Dej_t.sum()
            counter += 1
            fj_t = 1.0 - torch.exp(-torch.floor(Pj_t / (Rj_t + 1.0e-20))) # Capture rate
            Ci_t = tau * torch.sum(Sij_t * fj_t, dim=2)
            Ai_t += dt * (eta * P_off_t * Ii_t - Ci_t) # Time step for Ai and Ii
            Ii_t += -dt * eta * P_off_t * Ii_t
            t += dt

    Rj_t = Rj_t.cpu().numpy() if hasattr(Rj_t, 'cpu') else Rj_t

    scaler = MinMaxScaler()
    Rj_scaled = scaler.fit_transform(Rj_t.reshape(-1, 1)).flatten()

    # Preparar los datos
    x = np.arange(len(Rj_scaled))
    y = Rj_scaled

    # Detectar picos en los datos originales
    peaks, _ = find_peaks(y, prominence=0.1)

    if len(peaks) == 0:
        # If no peaks are found, return a flat line at the mean
        lowess_full_curve = np.full_like(x, np.mean(y))
    else:
        peaks = np.insert(peaks, 0, 0)
        peaks = np.append(peaks, len(y)-1)

        # Filtrar los valores de los picos
        x_peaks = x[peaks]
        y_peaks = y[peaks]

        # Lowess
        lowess = sm.nonparametric.lowess(y_peaks, x_peaks, frac=0.1)
        lowess_x = lowess[:, 0]
        lowess_y = lowess[:, 1]

        # El resultado de LOWESS solo tiene puntos en los picos. Para una comparación
        # justa, lo interpolamos para que tenga la misma longitud que los datos reales.
        lowess_full_curve = np.interp(x, lowess_x, lowess_y)

    timer1 = time.time()
    print("Total execution time: ", timer1 - timer0)

    return lowess_full_curve

# %%
from scipy.optimize import differential_evolution

def objective_function(params, dij, Ii, Zj, target_results):
    beta_r, gamma_r, alpha_p, gamma_p = params

    # Simulación con parámetros actuales
    simulation_results = run_simulation(dij, Ii, Zj, beta_r, gamma_r, alpha_p, gamma_p)

    # Evaluación de la diferencia con los resultados esperados
    error = np.linalg.norm(simulation_results - target_results)

    print(f"L-BFGS-B - Error: {error}\n, Params: {params}")

    return error

# %%
from scipy.optimize import minimize
import time

# Límites de búsqueda para cada parámetro
# 0.1        0.19482765 0.97356374 0.03415131
bounds = [(0.08, 0.12), (0.17, 0.19), (0.04, 0.06), (0.01, 0.03)]

# Valores iniciales
initial_params = [0.1, 0.1, 0.09, 0.003]

start_time = time.time()

# Optimización con descenso de gradiente
result_lbfgsd = minimize(
    objective_function,
    initial_params,
    args=(dij, Ii, Zj, scaled_targets),
    bounds=bounds,
    method='L-BFGS-B',
    options={'gtol': 1e-9, 'disp':True, 'maxiter':10}
    )

print("Parámetros óptimos encontrados:", result_lbfgsd.x)
print("Error final:", result_lbfgsd.fun)
end_time = time.time()
elapsed_time = end_time - start_time
print("Tiempo de ejecución:", elapsed_time, "segundos")
# Out:
# /tmp/ipython-input-560805216.py:14: DeprecationWarning: scipy.optimize: The `disp` and `iprint` options of the L-BFGS-B solver are deprecated and will be removed in SciPy 1.18.0.
#   result_lbfgsd = minimize(
# Starting loop ...
# Total execution time:  3.4992260932922363
# L-BFGS-B - Error: 0.9127589472704117
# , Params: [0.1  0.17 0.06 0.01]
# Starting loop ...
# Total execution time:  3.33166766166687
# L-BFGS-B - Error: 0.9127589520046613
# , Params: [0.10000001 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3133232593536377
# L-BFGS-B - Error: 0.9127589472704117
# , Params: [0.1        0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3176798820495605
# L-BFGS-B - Error: 0.9127589472704117
# , Params: [0.1        0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.308377981185913
# L-BFGS-B - Error: 0.9127589472704117
# , Params: [0.1        0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.3118655681610107
# L-BFGS-B - Error: 0.8968215553517185
# , Params: [0.08 0.17 0.06 0.01]
# Starting loop ...
# Total execution time:  3.3112809658050537
# L-BFGS-B - Error: 0.8968215548426159
# , Params: [0.08000001 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3115673065185547
# L-BFGS-B - Error: 0.8968215553517185
# , Params: [0.08       0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3368403911590576
# L-BFGS-B - Error: 0.8968215553517185
# , Params: [0.08       0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.312980890274048
# L-BFGS-B - Error: 0.8968215553517185
# , Params: [0.08       0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.3091650009155273
# L-BFGS-B - Error: 0.9024657209548876
# , Params: [0.0819419 0.17      0.06      0.01     ]
# Starting loop ...
# Total execution time:  3.306497573852539
# L-BFGS-B - Error: 0.9024657204504745
# , Params: [0.08194191 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3059141635894775
# L-BFGS-B - Error: 0.9024657209548876
# , Params: [0.0819419  0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.30062198638916
# L-BFGS-B - Error: 0.9024657209548876
# , Params: [0.0819419  0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.3006136417388916
# L-BFGS-B - Error: 0.9024657209548876
# , Params: [0.0819419  0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.300706386566162
# L-BFGS-B - Error: 0.8968212710829214
# , Params: [0.08000559 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.330437660217285
# L-BFGS-B - Error: 0.8968212705746724
# , Params: [0.0800056 0.17      0.06      0.01     ]
# Starting loop ...
# Total execution time:  3.314772129058838
# L-BFGS-B - Error: 0.8968212710829214
# , Params: [0.08000559 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3070456981658936
# L-BFGS-B - Error: 0.8968212710829214
# , Params: [0.08000559 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.3267581462860107
# L-BFGS-B - Error: 0.8968212710829214
# , Params: [0.08000559 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.334312915802002
# L-BFGS-B - Error: 0.896811357283538
# , Params: [0.08021243 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.311016082763672
# L-BFGS-B - Error: 0.8968113568069244
# , Params: [0.08021244 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3065998554229736
# L-BFGS-B - Error: 0.896811357283538
# , Params: [0.08021243 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3435802459716797
# L-BFGS-B - Error: 0.896811357283538
# , Params: [0.08021243 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.3062868118286133
# L-BFGS-B - Error: 0.896811357283538
# , Params: [0.08021243 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.297213315963745
# L-BFGS-B - Error: 0.8967758192244536
# , Params: [0.08107716 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.303828001022339
# L-BFGS-B - Error: 0.8967758188790375
# , Params: [0.08107717 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.326594829559326
# L-BFGS-B - Error: 0.8967758192244536
# , Params: [0.08107716 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3030941486358643
# L-BFGS-B - Error: 0.8967758192244536
# , Params: [0.08107716 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.2983756065368652
# L-BFGS-B - Error: 0.8967758192244536
# , Params: [0.08107716 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.305590867996216
# L-BFGS-B - Error: 0.8910269822094599
# , Params: [0.08335022 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.304231882095337
# L-BFGS-B - Error: 0.8910269814232925
# , Params: [0.08335023 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.2953121662139893
# L-BFGS-B - Error: 0.8910269822094599
# , Params: [0.08335022 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.299377679824829
# L-BFGS-B - Error: 0.8910269822094599
# , Params: [0.08335022 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.321497678756714
# L-BFGS-B - Error: 0.8910269822094599
# , Params: [0.08335022 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.293168306350708
# L-BFGS-B - Error: 0.9071821026683079
# , Params: [0.09244246 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3104074001312256
# L-BFGS-B - Error: 0.9071821037564795
# , Params: [0.09244247 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3106839656829834
# L-BFGS-B - Error: 0.9071821026683079
# , Params: [0.09244246 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3044731616973877
# L-BFGS-B - Error: 0.9071821026683079
# , Params: [0.09244246 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.297651767730713
# L-BFGS-B - Error: 0.9071821026683079
# , Params: [0.09244246 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.303931474685669
# L-BFGS-B - Error: 0.8910217530154617
# , Params: [0.08341715 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3248462677001953
# L-BFGS-B - Error: 0.8910217522389843
# , Params: [0.08341716 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.29524827003479
# L-BFGS-B - Error: 0.8910217530154617
# , Params: [0.08341715 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.2912051677703857
# L-BFGS-B - Error: 0.8910217530154617
# , Params: [0.08341715 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.297292470932007
# L-BFGS-B - Error: 0.8910217530154617
# , Params: [0.08341715 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.330991506576538
# L-BFGS-B - Error: 0.8913339929733911
# , Params: [0.08878043 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.303236961364746
# L-BFGS-B - Error: 0.8913339929419534
# , Params: [0.08878044 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3124475479125977
# L-BFGS-B - Error: 0.8913339929733911
# , Params: [0.08878043 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3172810077667236
# L-BFGS-B - Error: 0.8913339929733911
# , Params: [0.08878043 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.314134359359741
# L-BFGS-B - Error: 0.8913339929733911
# , Params: [0.08878043 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.3020944595336914
# L-BFGS-B - Error: 0.8913350714999921
# , Params: [0.08955173 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.307021141052246
# L-BFGS-B - Error: 0.8913350715698268
# , Params: [0.08955174 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.361001491546631
# L-BFGS-B - Error: 0.8913350714999921
# , Params: [0.08955173 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.328996181488037
# L-BFGS-B - Error: 0.8913350714999921
# , Params: [0.08955173 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.3292627334594727
# L-BFGS-B - Error: 0.8913350714999921
# , Params: [0.08955173 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.3260340690612793
# L-BFGS-B - Error: 0.8913332443925277
# , Params: [0.08906178 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3221428394317627
# L-BFGS-B - Error: 0.891333244398147
# , Params: [0.08906179 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3188605308532715
# L-BFGS-B - Error: 0.8913332443925277
# , Params: [0.08906178 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.309119462966919
# L-BFGS-B - Error: 0.8913332443925277
# , Params: [0.08906178 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.3229594230651855
# L-BFGS-B - Error: 0.8913332443925277
# , Params: [0.08906178 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.364572525024414
# L-BFGS-B - Error: 0.8913332323575535
# , Params: [0.08901912 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3408730030059814
# L-BFGS-B - Error: 0.8913332323575582
# , Params: [0.08901913 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3351502418518066
# L-BFGS-B - Error: 0.8913332323575535
# , Params: [0.08901912 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.4232265949249268
# L-BFGS-B - Error: 0.8913332323575535
# , Params: [0.08901912 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.3504583835601807
# L-BFGS-B - Error: 0.8913332323575535
# , Params: [0.08901912 0.17       0.06       0.01000001]
# Starting loop ...
# Total execution time:  3.3345954418182373
# L-BFGS-B - Error: 0.8913332323575458
# , Params: [0.08901908 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3124191761016846
# L-BFGS-B - Error: 0.8913332323575464
# , Params: [0.08901909 0.17       0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.307426691055298
# L-BFGS-B - Error: 0.8913332323575458
# , Params: [0.08901908 0.17000001 0.06       0.01      ]
# Starting loop ...
# Total execution time:  3.3155906200408936
# L-BFGS-B - Error: 0.8913332323575458
# , Params: [0.08901908 0.17       0.05999999 0.01      ]
# Starting loop ...
# Total execution time:  3.324263334274292
# L-BFGS-B - Error: 0.8913332323575458
# , Params: [0.08901908 0.17       0.06       0.01000001]
# Parámetros óptimos encontrados: [0.08901908 0.17       0.06       0.01      ]
# Error final: 0.8913332323575458
# Tiempo de ejecución: 233.18340468406677 segundos

# %% [markdown]
# ##### 3.4.5.1 Results L-BFGS-B

# %%
def calculate_errors_sklearn(predicted, real):

    predicted = predicted.flatten()
    real = real.flatten()

    mse = mean_squared_error(real, predicted)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(real, predicted)
    r2 = r2_score(real, predicted)

    metrics = {
        "rmse": rmse,
        "mae": mae,
        "r2": r2,
        "max_error": np.max(np.abs(real - predicted))
    }

    return metrics

def print_detailed_comparison_sklearn(predicted, real):
    metrics = calculate_errors_sklearn(predicted, real)

    print("Métricas de error:")
    print(f"RMSE: {metrics['rmse']:.4f}")
    print(f"MAE: {metrics['mae']:.4f}")
    print(f"R² Score: {metrics['r2']:.4f}")
    print(f"Error máximo: {metrics['max_error']:.4f}")

# %%
def plot_results(Zj, Rj, algorithm):

    # Crear una figura con dos subplots verticales
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

    # Agregar un título general
    fig.suptitle(f"Comparison of Riot Targets: Simulation {algorithm} vs Zj (real values SOSAFE)", fontsize=16, y=1.05)

    # Primer subplot para Zj
    x1 = np.arange(len(Zj))
    y1 = Zj
    ax1.plot(x1, y1)
    ax1.set_xlabel('Target Points')
    ax1.set_ylabel('Rioters')
    ax1.set_title('Line Plot of Zj')
    ax1.grid(True, linestyle='--', alpha=0.5)

    # Segundo subplot para Rj
    x2 = np.arange(len(Rj))
    y2 = Rj
    ax2.plot(x2, y2)
    ax2.set_xlabel('Target Points')
    ax2.set_ylabel('Rioters')
    ax2.set_title('Line Plot of Rj')
    ax2.grid(True, linestyle='--', alpha=0.5)

    # Ajustar el espaciado entre subplots
    plt.tight_layout()

    # Mostrar la figura
    plt.show()

# %%
rioters_lbfgsd = run_simulation(dij, Ii, Zj, result_lbfgsd.x[0], result_lbfgsd.x[1], result_lbfgsd.x[2], result_lbfgsd.x[3])
# Out:
# Starting loop ...
# Total execution time:  3.3322367668151855

# %%
plot_results(scaled_targets, rioters_lbfgsd, "L-BFGS-B")

# %%
print_detailed_comparison_sklearn(rioters_lbfgsd, scaled_targets)
# Out:
# Métricas de error:
# RMSE: 0.0399
# MAE: 0.0357
# R² Score: 0.9110
# Error máximo: 0.1607
